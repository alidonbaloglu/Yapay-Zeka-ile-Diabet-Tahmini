# %%
#makine öğrenmesi projesini kullanıma uygun hale getimek için arayüz yapmamız gerekiyor bunun 
#için tkinter üzerinden bir arayüz geliştirdim

# %%
from tkinter import *
from tkinter import messagebox
from tkinter import filedialog
from tkinter.ttk import Combobox
from tkinter import messagebox
from tkinter import Canvas
from tkinter import ttk

# %%
import numpy as np
import pandas as pd
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import model_selection
from sklearn.metrics import accuracy_score

from warnings import filterwarnings
filterwarnings('ignore')

# %%
#önceki bölümde oluşturduğumuz modeli buraya uyguluyoruz

# %%
df = pd.read_csv(r"diabetes2.csv")
df = df.drop(["Unnamed: 0"],axis=1)
df=df.dropna()

# %%
y = df["Outcome"]
X = df.drop(["Outcome"], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.30, 
                                                    random_state = 42)

# %%
xgb_model = XGBClassifier().fit(X_train, y_train)
# Out:
# [10:40:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
y_pred = xgb_model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.74235807860262

# %%
xgb = XGBClassifier(learning_rate = 0.05, 
                    max_depth = 5,
                    min_samples_split = 2,
                    n_estimators = 100,
                    subsample = 1.0)

# %%
xgb_tuned =  xgb.fit(X_train,y_train)
# Out:
# [10:40:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "min_samples_split" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [10:40:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
y_pred = xgb_tuned.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7729257641921398

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0             72           35.0        0  33.6
# 1            1.0     85.0             66           29.0        0  26.6
# 2            8.0    183.0             64            0.0        0  23.3
# 3            1.0     89.0             66           23.0       94  28.1
# 4            0.0    137.0             40           35.0      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0             76           48.0      180  32.9
# 764          2.0    122.0             70           27.0        0  36.8
# 765          5.0    121.0             72           23.0      112  26.2
# 766          1.0    126.0             60            0.0        0  30.1
# 767          1.0     93.0             70           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Arayüz Oluşturma

# %%
pencere = Tk()
pencere.title("Ev Fiyat Tahmini")

pencere.configure(background='#062B39')
pencere.geometry("560x700")
pencere.state("normal")


def olumsuz():
    messagebox.showwarning(title="Dikkat", message="Seçim Yapmadınız")

# DEĞİŞKENLER


def pregnancies_düzenle():
    global Pregnancies
    pregnancies = int(pregnancies_entry.get())
    if(pregnancies > 0):
        Pregnancies = pregnancies
        
        print(pregnancies)
    else:
        olumsuz()
    

def glucose_düzenle():
    global Glucose
    glucose = float(glucose_entry.get())
    if(glucose > 0):
        Glucose = glucose
        print(glucose)
       
    else:
        olumsuz()

def bloodPressure_düzenle():
    global BloodPressure
    bloodPressure = int(bloodPressure_entry.get())
    if(bloodPressure > 0):
        BloodPressure = bloodPressure
        
        print(bloodPressure)
    else:
        olumsuz()
    

def skinThickness_düzenle():
    global SkinThickness
    skinThickness = float(skinThickness_entry.get())
    if(skinThickness > 0):
        SkinThickness = skinThickness
        print(skinThickness)
       
    else:
        olumsuz()
        

def insulin_düzenle():
    global Insulin
    insulin = int(insulin_entry.get())
    if(insulin >= 0):
        Insulin = insulin
        
        print(insulin)
    else:
        olumsuz()
    

def bmi_düzenle():
    global BMI
    bmi = float(bmi_entry.get())
    if(bmi > 0):
        
        
        BMI = bmi
        print(bmi)
       
    else:
        olumsuz()
        
def diabetesPedigreeFunction_düzenle():
    global DiabetesPedigreeFunction
    diabetesPedigreeFunction = float(diabetesPedigreeFunction_entry.get())
    if(diabetesPedigreeFunction > 0):
        DiabetesPedigreeFunction = diabetesPedigreeFunction
        
        print(diabetesPedigreeFunction)
    else:
        olumsuz()
    

def age_düzenle():
    global Age
    age = int(age_entry.get())
    if(age > 0):
        Age = age
        print(age)
       
    else:
        olumsuz()

       
        
baslık_label = Label(pencere, text = "DİABET TAHMİNİ", font="Verdana 25 bold",borderwidth=1, padx = 100, pady = 20,
                   background = "#CB9C67",fg="#067860")        
baslık_label.place(x = 20 ,y = 10)
        
        


# Pregnancies
pregnancies_label = Label(text = "Pregnancies", font="Verdana 13 bold",borderwidth=6,fg="red")
pregnancies_label.place(x = 80, y = 120)

pregnancies_entry = Entry()
pregnancies_entry.place(x = 280, y = 125)

pregnancies_buton = Button(pencere, text = "Onayla", command = pregnancies_düzenle, font="helvetica 12",borderwidth=6,background="#F2B663")
pregnancies_buton.place(x = 420, y = 120)

# Glucose
glucose_label = Label(pencere, text = "Glucose", font="Verdana 13 bold",borderwidth=6,fg="red")
glucose_label.place(x = 80, y = 170)

glucose_entry = Entry()
glucose_entry.place(x = 280, y = 175)

glucose_buton = Button(pencere, text = "Onayla", command = glucose_düzenle, font="helvetica 12",borderwidth=6,background="#F2B663")
glucose_buton.place(x = 420, y = 170)

# Blood Pressure
bloodPressure_label = Label(text = "Blood Pressure", font="Verdana 13 bold",borderwidth=6,fg="red")
bloodPressure_label.place(x = 80, y = 220)

bloodPressure_entry = Entry()
bloodPressure_entry.place(x = 280, y = 225)

bloodPressure_buton = Button(pencere, text = "Onayla", command = bloodPressure_düzenle, font="helvetica 12",borderwidth=6,background="#F2B663")
bloodPressure_buton.place(x = 420, y = 220)

# Skin Thickness
skinThickness_label = Label(pencere, text = "Skin Thickness", font="Verdana 13 bold",borderwidth=6,fg="red")
skinThickness_label.place(x = 80, y = 270)

skinThickness_entry = Entry()
skinThickness_entry.place(x = 280, y = 275)

skinThickness_buton = Button(pencere, text = "Onayla", command = skinThickness_düzenle, font="helvetica 12",borderwidth=6,background="#F2B663")
skinThickness_buton.place(x = 420, y = 270)

# Insulin
insulin_label = Label(text = "Insulin", font="Verdana 13 bold",borderwidth=6,fg="red")
insulin_label.place(x = 80, y = 320)

insulin_entry = Entry()
insulin_entry.place(x = 280, y = 325)

insulin_buton = Button(pencere, text = "Onayla", command = insulin_düzenle, font="helvetica 12",borderwidth=6,background="#F2B663")
insulin_buton.place(x = 420, y = 320)

# BMI
bmi_label = Label(pencere, text = "BMI", font="Verdana 13 bold",borderwidth=6,fg="red")
bmi_label.place(x = 80, y = 370)

bmi_entry = Entry()
bmi_entry.place(x = 280, y = 375)

bmi_buton = Button(pencere, text = "Onayla", command =bmi_düzenle, font="helvetica 12",borderwidth=6,background="#F2B663")
bmi_buton.place(x = 420, y = 370)

# Pedigree Function
diabetesPedigreeFunction_label = Label(text = "Pedigree Function", font="Verdana 13 bold",borderwidth=6,fg="red")
diabetesPedigreeFunction_label.place(x = 80, y = 420)

diabetesPedigreeFunction_entry = Entry()
diabetesPedigreeFunction_entry.place(x = 280, y = 425)

diabetesPedigreeFunction_buton = Button(pencere, text = "Onayla", command = diabetesPedigreeFunction_düzenle, font="helvetica 12",borderwidth=6,background="#F2B663")
diabetesPedigreeFunction_buton.place(x = 420, y = 420)

# Age
age_label = Label(pencere, text = "Age", font="Verdana 13 bold",borderwidth=6,fg="red")
age_label.place(x = 80, y = 470)

age_entry = Entry()
age_entry.place(x = 280, y = 475)

age_buton = Button(pencere, text = "Onayla",command = age_düzenle, font="helvetica 12",borderwidth=6,background="#F2B663")
age_buton.place(x = 420, y = 470)


# makine öğrenmesi kısmı

def hesapla():

    #girilen verileri bizim hazırladğımız veri halinde dataframeye kaydediyoruz  
    yeni_veri = [[Pregnancies],[Glucose],[BloodPressure],[SkinThickness],[Insulin],[BMI],[DiabetesPedigreeFunction],[Age]] 
    yeni_veri = pd.DataFrame(yeni_veri).T
    
    df_2 = yeni_veri.rename(columns = {0:"Pregnancies",
                        1:"Glucose",
                        2:"BloodPressure",
                        3:"SkinThickness",
                        4:"Insulin",
                        5:"BMI",
                        6:"DiabetesPedigreeFunction",
                       7:"Age"})
    #tahmin işlemini yaptırıyoruz 
    
    pred = xgb_tuned.predict(df_2)
    #s2 = Label(pencere, text = pred, font="Verdana 25 bold",borderwidth=6, padx = 100, pady = 40)
    #s2.place(x = 650, y = 510) 
    
    if(pred == 0):
        s1 = Label(pencere, text= "Negatif", font="helvetica 20",borderwidth=30, padx = 40, pady = 10)
        s1.place(x = 280, y = 540)
    else:
        s1 = Label(pencere, text= "Pozitif", font="helvetica 20",borderwidth=30, padx = 40, pady = 10)
        s1.place(x = 280, y = 540)
    
"""  
    if(pred == 0):
        print("Negatif")
    else:
        print("Pozitif")
"""
    
   
    
# HESAPLA
hesapla_buton = Button(pencere, text = "HESAPLA", command = hesapla, font="helvetica 15",borderwidth=30, padx = 40, pady = 10, background = "#E5CDA8")
hesapla_buton.place(x = 20, y = 540)



# HAKKINDA
hakkında_label = Label(pencere, text = "ALİ CAN DONBALOĞLU",background = "deep sky blue",fg="black",font="Times 10 italic")
hakkında_label.place(x = 5, y = 670)

mainloop()
# Out:
# 5
# 5.0
# 5
# 5.0
# 5
# 5.0
# 5.0
# 5
